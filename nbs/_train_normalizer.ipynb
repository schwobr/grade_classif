# %%
# default_exp train_normalizer

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# export
from grade_classif.params.parser import hparams
from grade_classif.train import train_normalizer

# %%
# export
model = train_normalizer(hparams)
# Out:
# INFO:root:gpu available: True, used: True
# INFO:root:VISIBLE GPUS: 0
# INFO:root:
#                           Name              Type Params
# 0                         unet       DynamicUnet   27 M
# 1                 unet.encoder        Sequential   21 M
# 2               unet.encoder.0            Conv2d    9 K
# 3               unet.encoder.1       BatchNorm2d  128
# 4               unet.encoder.2              ReLU    0
# 5               unet.encoder.3         MaxPool2d    0
# 6               unet.encoder.4        Sequential  221 K
# 7             unet.encoder.4.0        BasicBlock   73 K
# 8       unet.encoder.4.0.conv1            Conv2d   36 K
# 9         unet.encoder.4.0.bn1       BatchNorm2d  128
# 10       unet.encoder.4.0.relu              ReLU    0
# 11      unet.encoder.4.0.conv2            Conv2d   36 K
# 12        unet.encoder.4.0.bn2       BatchNorm2d  128
# 13            unet.encoder.4.1        BasicBlock   73 K
# ...

# %%
#hide
from nbdev.export import notebook2script
notebook2script(fname='_train_normalizer.ipynb')
# Out:
# Converted _train_normalizer.ipynb.
