# %%
from grade_classif.imports import *
from grade_classif.params.parser import hparams
from grade_classif.models.plmodules import *
from grade_classif.data.read import get_items
from grade_classif.data.loaders import ImageLoader
from grade_classif.data.utils import np_to_tensor
from grade_classif.data.transforms import get_transforms1
from grade_classif.data.modules import *
from grade_classif.data.dataset import TestDataset
from skimage.color import rgb2hed, rgb2hsv, hsv2rgb
from fastai.data.transforms import get_files
from torch.utils.data import Dataset, DataLoader
from fastcore.foundation import L
from openslide import OpenSlide
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from albumentations.augmentations.functional import resize
from sklearn.metrics import auc
from pytorch_lightning.metrics import ROC, ConfusionMatrix
from grade_classif.models.metrics import ClassifMetrics
import PIL.Image as Image
from math import ceil

# %%
classes = ["1", "3"]
n_classes = len(classes)
model_name = "resnet50"
level = 1
version = "15bd5219d3244bd4959c5913e322ac61"
save_path = Path(f"/data/DeepLearning/SCHWOB_Robin/models/logs/level_{level}/classifier/{model_name}/lightning_logs/version_{version}")

# %%
df = pd.read_csv(save_path/"preds/14.csv")

# %%
df.head()
# Out:
#                                                                                                                                                                                     item  \
# 0        /data/DeepLearning/SCHWOB_Robin/Projet_Pauline/Patches_cancer_1024/Patches_cancer_1024_1/DHL_THL/PG_ThésePaulineHE1_18T034378HE1/PG_ThésePaulineHE1_18T034378HE1_annot0_0_0.png
# 1        /data/DeepLearning/SCHWOB_Robin/Projet_Pauline/Patches_cancer_1024/Patches_cancer_1024_1/DHL_THL/PG_ThésePaulineHE1_18T034378HE1/PG_ThésePaulineHE1_18T034378HE1_annot2_0_0.png
# 2     /data/DeepLearning/SCHWOB_Robin/Projet_Pauline/Patches_cancer_1024/Patches_cancer_1024_1/DHL_THL/PG_ThésePaulineHE1_18T034378HE1/PG_ThésePaulineHE1_18T034378HE1_annot2_1120_0.png
# 3     /data/DeepLearning/SCHWOB_Robin/Projet_Pauline/Patches_cancer_1024/Patches_cancer_1024_1/DHL_THL/PG_ThésePaulineHE1_18T034378HE1/PG_ThésePaulineHE1_18T034378HE1_annot2_0_1120.png
# 4  /data/DeepLearning/SCHWOB_Robin/Projet_Pauline/Patches_cancer_1024/Patches_cancer_1024_1/DHL_THL/PG_ThésePaulineHE1_18T034378HE1/PG_ThésePaulineHE1_18T034378HE1_annot2_1120_1120.png
#
#    label  pred_NoReargmt  pred_DHL_THL
# 0      1        0.996784      0.003216
# 1      1        0.827201      0.172799
# 2      1        0.952309      0.047691
# 3      1        0.928668      0.071332
# 4      1        0.942771      0.057229

# %%
items = np.vectorize(Path)(df.values[:, 0])
preds = torch.as_tensor(df.values[:, 2:].astype(np.float32))
labels = torch.as_tensor(df.values[:, 1].astype(int))

# %%
df = pd.read_csv("/data/DeepLearning/SCHWOB_Robin/Patches_FLFH_299/scan_splits.csv")

# %%
items = get_files(
    "/data/DeepLearning/SCHWOB_Robin/Patches_cancer_1024/Patches_cancer_1024_1",
    extensions=[".png"],
).filter(lambda x: "PACS04" not in x.name)

# %%
device = torch.device("cuda:1")

# %%
model = torch.jit.load(
    str(save_path / "best_model.pt"),
    map_location=device,
).eval()

# %%
for p in model.parameters():
    p.requires_grad = False

# %%
ds = TestDataset(items[len(preds):])

# %%
dl = DataLoader(ds, batch_size=8, num_workers=4, pin_memory=True, shuffle=False, drop_last=False)

# %%
labels = items.map(lambda x: x.parts[-3])

# %%
labels = torch.as_tensor(np.array(labels) == "3").long()

# %%
preds_1 = []
for x in tqdm(dl):
    x = x.to(device, non_blocking=True)
    with torch.cuda.amp.autocast():
        y = model(x).detach()
        y = torch.softmax(y, dim=1)
    preds_1.append(y.cpu())
preds_1 = torch.cat(preds_1)
# Out:
#   0%|          | 0/587 [00:00<?, ?it/s]

# %%
preds_np = preds.numpy()
labels_np = labels.numpy()
items_str = np.array(items).astype(str)
data = {
    f"pred_{classes[k]}": preds_np[:, k]
    for k in range(preds_np.shape[1])
}
data["item"] = items_str[: labels.shape[0]]
data["label"] = labels_np
keys = ["item", "label"] + [f"pred_{cl}" for cl in classes]
df = pd.DataFrame(data=data, columns=keys)
df.to_csv(save_path / "preds/test.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-44ee7da2b9ca> in <module>
#       9 data["label"] = labels_np
#      10 keys = ["item", "label"] + [f"pred_{cl}" for cl in classes]
# ---> 11 df = pd.DataFrame(data=data, columns=keys)
#      12 df.to_csv(save_path / "preds/test.csv", index=False)
#
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/fastai/torch_core.py in __init__(self, data, index, columns, dtype, copy)
#     482 def __init__(self:pd.DataFrame, data=None, index=None, columns=None, dtype=None, copy=False):
#     483     if data is not None and isinstance(data, Tensor): data = to_np(data)
# --> 484     self._old_init(data, index=index, columns=columns, dtype=dtype, copy=copy)
#     485
#     486 # Cell
#
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     256             # GH10856
#     257             # raise ValueError if only scalars in dict
# --> 258             index = extract_index(arrays[~missing])
#     259         else:
#     260             index = ensure_index(index)
#
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
roc = ROC(num_classes=n_classes)
# Out:
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.

# %%
fpr, tpr, thrs = roc(preds, labels)

# %%
k = torch.argmin(fpr[-1]**2+(1-tpr[-1])**2)
best_thr = thrs[-1][k].item(); best_thr, fpr[-1][k], tpr[-1][k]
# Out:
# (0.8550309538841248, tensor(0.4485), tensor(0.6164))

# %%
plt.plot(fpr[-1].cpu(), tpr[-1].cpu())

# %%
auc(fpr[-1], tpr[-1])
# Out:
# 0.6306702494621277

# %%
cm = ConfusionMatrix(n_classes, threshold=best_thr, normalize="true")
metrics = ClassifMetrics(n_classes, threshold=best_thr)

# %%
mat = cm(preds[:, -1], labels)
metric_dict = metrics(preds[:, -1], labels)

# %%
cm_plot = ConfusionMatrixDisplay(mat.numpy(), display_labels=classes)

# %%
cm_plot.plot(cmap=plt.cm.Blues)

# %%
patch_slides = np.vectorize(lambda x: x.parent.name)(items)
slides = np.unique(patch_slides)

# %%
slides = slides[np.vectorize(lambda x: "PACS05" in x)(slides)]

# %%
slide_roc = ROC(num_classes=n_classes, compute_on_step=False)
# Out:
# //home/DeepLearning/anaconda3/envs/pytorch/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.

# %%
slide_labels = []
slide_preds = []
for slide in slides:
    idxs = np.argwhere(patch_slides == slide).squeeze()
    label = labels[idxs][0]
    pred = preds[idxs].mean(0)
    slide_roc(pred[None], label[None])
    slide_labels.append(label)
    slide_preds.append(pred)
slide_labels = torch.stack(slide_labels)
slide_preds = torch.stack(slide_preds)

# %%
fpr, tpr, thrs = slide_roc.compute()

# %%
k = torch.argmin(fpr[-1]**2+(1-tpr[-1])**2)
best_thr = thrs[-1][k].item(); best_thr, fpr[-1][k], tpr[-1][k]
# Out:
# (0.6700080633163452, tensor(0.2857), tensor(0.6591))

# %%
plt.plot(fpr[-1].cpu(), tpr[-1].cpu())
plt.title(f"AUC={auc(fpr[-1], tpr[-1]):.3f}")
plt.show()

# %%
cm = ConfusionMatrix(n_classes, threshold=0.5, normalize="true")
metrics = ClassifMetrics(n_classes, threshold=0.5)

# %%
mat = cm(slide_preds[:, -1], slide_labels)
metric_dict = metrics(slide_preds[:, -1], slide_labels)

# %%
cm_plot = ConfusionMatrixDisplay(mat.numpy(), display_labels=classes)

# %%
(slide_labels == 1).sum(), (slide_labels == 0).sum()
# Out:
# (tensor(220), tensor(28))

# %%
cm_plot.plot(cmap=plt.cm.Blues)

# %%
metric_dict
# Out:
# {'precision': tensor([0.2857, 0.9296]),
#  'recall': tensor([0.5000, 0.8409]),
#  'f1': tensor([0.3636, 0.8831]),
#  'accuracy': tensor(0.8024)}

# %%
for pacs in ("05", "08"):
    idxs = np.argwhere(np.vectorize(lambda x: x[7:9])(slides) == pacs).squeeze(1)
    print(len(idxs), len(np.argwhere(slide_labels[idxs] == 1).squeeze()))
# Out:
# 248 220
# 351 328

# %%
idxs = torch.nonzero((slide_preds[:, -1] >= 0.5).long() != slide_labels, as_tuple=False).squeeze()
print(len(idxs), len(slides)) 
print('\n'.join([f"{slide}-{classes[cl]}-{pred[1]:.3f}" for slide, cl, pred in zip(slides[idxs], slide_labels[idxs], slide_preds[idxs])]))
# Out:
# 77 599
# CF_PACS05HE_01002-779160-1-0.596
# CF_PACS05HE_01025-918616-3-0.428
# CF_PACS05HE_01033-200568RH-3-0.375
# CF_PACS05HE_01051-201733-3-0.355
# CF_PACS05HE_02008-03.3186.02.02-3-0.458
# CF_PACS05HE_02013-04.0348.02.00-1-0.890
# CF_PACS05HE_02022-04.4936.02.00-3-0.423
# CF_PACS05HE_04004-124560-3-0.486
# CF_PACS05HE_04006-125010-3-0.139
# CF_PACS05HE_04011-125651-3-0.417
# CF_PACS05HE_04051-131293-1-0.754
# CF_PACS05HE_04062-131628-3-0.238
# CF_PACS05HE_04082-134280-3-0.287
# CF_PACS05HE_04091-135498-3-0.495
# CF_PACS05HE_04115-140742-1-0.625
# CF_PACS05HE_05031-05B4086.3GSDP-1-0.937
# CF_PACS05HE_06006-173.091-3-0.459
# CF_PACS05HE_06007-173.181I-3-0.452
# CF_PACS05HE_06011-173.961I-3-0.380
# CF_PACS05HE_06019-175.497I-3-0.335
# CF_PACS05HE_06056-182.964IC-3-0.251
# CF_PACS05HE_06059-183.058IC-3-0.308
# CF_PACS05HE_06062-183.834IC-3-0.400
# CF_PACS05HE_06070-185.621IB-1-0.854
# CF_PACS05HE_07013-GH890T-3-0.431
# CF_PACS05HE_07025-GN425T-3-0.386
# CF_PACS05HE_07034-GR599Tb-3-0.418
# CF_PACS05HE_08009-A02.3597III1-1-0.526
# CF_PACS05HE_08033-A03.3779II1-1-0.745
# CF_PACS05HE_08039-A04.74I1-3-0.485
# CF_PACS05HE_08084-A04.4476II1-1-0.589
# CF_PACS05HE_08088-A05.298II1-3-0.455
# CF_PACS05HE_08135-A06.2369I2-1-0.931
# CF_PACS05HE_12004-356330-7C-3-0.440
# CF_PACS05HE_12006-357955-7-3-0.436
# CF_PACS05HE_12025-365958-6B-3-0.094
# CF_PACS05HE_12026-366595-2-3-0.160
# CF_PACS05HE_13002-C02.4922-5-3-0.472
# CF_PACS05HE_13032-C03.4150-7-3-0.265
# CF_PACS05HE_13048-C04.895-1-3-0.412
# CF_PACS05HE_13052-C04.1514-6-1-0.661
# CF_PACS05HE_13062-C04.5014-4-1-0.925
# CF_PACS05HE_13068-C05.1607-1-3-0.203
# CF_PACS05HE_15001-2310770-3-0.311
# CF_PACS05HE_18001-03P02994-3-0.478
# CF_PACS05HE_18003-03P04248-1-0.670
# CF_PACS05HE_18010-04P06509-1-0.769
# CF_PACS05HE_30015-04.2952.1-3-0.468
# CF_PACS05HE_54022-H0501438-3-0.331
# CF_PACS08rescan_008-07C4550-1-0.974
# CF_PACS08rescan_027-09C2704-1-0.552
# CF_PACS08rescan_038-08C832-1-0.945
# CF_PACS08rescan_101-08C4280-1-0.840
# CF_PACS08rescan_106-09C2708-3-0.348
# CF_PACS08rescan_135-08C3580-3-0.342
# CF_PACS08rescan_145-09C2710-3-0.455
# CF_PACS08rescan_172-08C5075-1-0.833
# CF_PACS08rescan_193-08C4245-1-0.799
# CF_PACS08rescan_224-11C2100-1-0.636
# CF_PACS08rescan_281-11C2533-3-0.455
# CF_PACS08rescan_305-09C0653-3-0.434
# CF_PACS08rescan_329-11C2113-1-0.547
# CF_PACS08rescan_341-09C2247-1-0.870
# CF_PACS08rescan_364-09C2531-1-0.826
# CF_PACS08rescan_368-11C2503-1-0.882
# CF_PACS08rescan_371-09C3755-1-0.944
# CF_PACS08rescan_410-09C4888-3-0.494
# CF_PACS08rescan_461-11C2167-1-0.854
# CF_PACS08rescan_525-10C0648-1-0.791
# CF_PACS08rescan_560-10C0182-1-0.908
# CF_PACS08rescan_568-09C5280-1-0.614
# CF_PACS08rescan_615-10C1982-1-0.884
# CF_PACS08rescan_659-10C0659-1-0.908
# CF_PACS08rescan_663-11C4747-1-0.935
# CF_PACS08rescan_685-10C2692-1-0.806
# CF_PACS08rescan_703-11C0121-1-0.851
# CF_PACS08rescan_746-10C3515-1-0.918

# %%
k = 0

# %%
slide = slides[k]

# %%
slide
# Out:
# 'CF_PACS04rescan_06P011'

# %%
patches = items[patch_slides == slide]

# %%
slide_preds = preds[patch_slides == slide, slide_labels[k]]

# %%
slide_labels[k]
# Out:
# tensor(1)

# %%
plt.figure(figsize=(10, 10))
x_coords = np.vectorize(lambda x: int(x.stem.split("_")[-2]) // 2048)(patches)
y_coords = np.vectorize(lambda x: int(x.stem.split("_")[-1]) // 2048)(patches)
h = max(y_coords) - min(y_coords) + 1
w = max(x_coords) - min(x_coords) + 1
thumb = OpenSlide(
    f"/home/DeepLearning/media/Isilon_robin/annot13/{slide}.mrxs"
).get_thumbnail((w * 128, h * 128))
mask = np.zeros((h, w), dtype=float)
mask[(y_coords, x_coords)] = slide_preds
mask = resize(mask, thumb.height, thumb.width)
# mask = (mask*255).astype(np.uint8)
plt.axis("off")
plt.imshow(mask, cmap="viridis")

# %%
files = get_files(
    "/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/",
    extensions=[".png"],
)
files
# Out:
# (#17781) [Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_40278_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_42196_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_44114_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_46032_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_49868_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_55622_61376.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_36442_63294.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_38360_63294.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_40278_63294.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_oncograde_1024/CF_OncogradeI-III_16T047813-9/CF_OncogradeI-III_16T047813-9.mrxs_42196_63294.png')...]

# %%
files = files.filter(lambda x: x.parent.name not in s); files
# Out:
# (#16853) [Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_26624_71680.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_28672_71680.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_24576_73728.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_26624_73728.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_28672_73728.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_75776_73728.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_22528_75776.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_28672_75776.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_30720_75776.png'),Path('/data/DeepLearning/SCHWOB_Robin/Patches_laas_1024/CF_PhD-LAAS-HE_10C3102/CF_PhD-LAAS-HE_10C3102.mrxs_22528_77824.png')...]

# %%
class TestDataset(Dataset):
    def __init__(self, items):
        self.items = items.map(str)
        
    def __len__(self):
        return len(self.items)
    
    def __getitem__(self, idx):
        item = self.items[idx]
        img = imread(item).astype(np.float32)
        return np_to_tensor(img / 255, "image")

# %%
ds = TestDataset(files)

# %%
dl = DataLoader(
    ds, batch_size=8, shuffle=False, num_workers=8, drop_last=False, pin_memory=True
)

# %%
device = torch.device("cuda:0")

# %%
model = torch.jit.load(
    "/data/DeepLearning/SCHWOB_Robin/models/logs/level_1/classifier/resnet34/lightning_logs/version_30e0285c100b4a5392ad238d42066814/best_model.pt",
    map_location=device,
).eval()

# %%
for p in model.parameters():
    p.requires_grad = False

# %%
preds = []
for x in tqdm(dl):
    x = x.to(device, non_blocking=True)
    with torch.cuda.amp.autocast():
        y = model(x).detach()
        y = torch.softmax(y, dim=1)
    preds.append(y.cpu())
preds = torch.cat(preds)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2223.0), HTML(value='')))

# %%
patch_slides = np.array(files.map(lambda x: x.parent.name))
slides = np.unique(patch_slides)

# %%
slide_preds = []
for slide in slides:
    if slide in s:
        continue
    idxs = np.argwhere(patch_slides == slide).squeeze(1)
    pred = preds[idxs].mean(0)
    print(f"{slide}: pred={pred[1]:.3f}")
    slide_preds.append(pred)
slide_preds = torch.stack(slide_preds)
# Out:
# CF_OncogradeI-III_16T015682-6: pred=0.715
# CF_OncogradeI-III_16T017703-8: pred=0.983
# CF_OncogradeI-III_16T017955-8: pred=0.916
# CF_OncogradeI-III_16T017965-18: pred=0.834
# CF_OncogradeI-III_16T018176-2: pred=0.905
# CF_OncogradeI-III_16T018176-5: pred=0.656
# CF_OncogradeI-III_16T018285-1: pred=0.448
# CF_OncogradeI-III_16T018715-3: pred=0.980
# CF_OncogradeI-III_16T019925-7: pred=0.410
# CF_OncogradeI-III_16T020155-7: pred=0.700
# CF_OncogradeI-III_16T020976-2: pred=0.657
# CF_OncogradeI-III_16T020993-2: pred=0.411
# CF_OncogradeI-III_16T021562-11: pred=0.578
# CF_OncogradeI-III_16T022194-14: pred=0.458
# CF_OncogradeI-III_16T022194-8: pred=0.694
# CF_OncogradeI-III_16T023783-2: pred=0.991
# CF_OncogradeI-III_16T024630-6: pred=0.948
# CF_OncogradeI-III_16T025936-6: pred=0.871
# CF_OncogradeI-III_16T025940-17: pred=0.951
# CF_OncogradeI-III_16T026429-9: pred=0.744
# CF_OncogradeI-III_16T028675-23: pred=0.859
# CF_OncogradeI-III_16T028943-9: pred=0.927
# CF_OncogradeI-III_16T028944-2: pred=0.826
# CF_OncogradeI-III_16T029509-15: pred=0.768
# CF_OncogradeI-III_16T029745-3: pred=0.745
# CF_OncogradeI-III_16T029757-13: pred=0.906
# CF_OncogradeI-III_16T029761-12: pred=0.971
# CF_OncogradeI-III_16T029762-4: pred=0.945
# CF_OncogradeI-III_16T031546-28: pred=0.972
# CF_OncogradeI-III_16T032845-8: pred=0.900
# CF_OncogradeI-III_16T033824-9: pred=0.576
# CF_OncogradeI-III_16T034032-21: pred=0.673
# CF_OncogradeI-III_16T034617-12: pred=0.365
# CF_OncogradeI-III_16T036135-3: pred=0.840
# CF_OncogradeI-III_16T041409-8: pred=0.916
# CF_OncogradeI-III_16T041411-6: pred=0.898
# CF_OncogradeI-III_16T041413-23: pred=0.583
# CF_OncogradeI-III_16T041656-10: pred=0.469
# CF_OncogradeI-III_16T041920-10: pred=0.961
# CF_OncogradeI-III_16T042865-8: pred=0.941
# CF_OncogradeI-III_16T042880-9: pred=0.963
# CF_OncogradeI-III_16T046784-16: pred=0.948
# CF_OncogradeI-III_16T047309-8: pred=0.844
# CF_OncogradeI-III_16T047311-9: pred=0.924
# CF_OncogradeI-III_16T047813-9: pred=0.971
# CF_OncogradeI-III_16T049252-2: pred=0.981
# CF_OncogradeI-III_16T050162-6: pred=0.683
# CF_OncogradeI-III_16T050164-5: pred=0.833
# CF_OncogradeI-III_16T050885-2: pred=0.907
# CF_OncogradeI-III_16T050962-18: pred=0.633
# CF_OncogradeI-III_16T050962-9: pred=0.937
# CF_OncogradeI-III_16T051428-4: pred=0.982
# CF_OncogradeI-III_16T052694-3: pred=0.940

# %%
preds = preds.numpy()
items = np.array(files).astype(str)
data = {
    f"pred_{classes[k]}": preds[:, k]
    for k in range(preds.shape[1])
}
data["item"] = items[: labels.shape[0]]
keys = ["item"] + [f"pred_{cl}" for cl in classes]
df = pd.DataFrame(data=data, columns=keys)
savepath = Path("/data/DeepLearning/SCHWOB_Robin/models/logs/level_1/classifier/resnet34/lightning_logs/version_30e0285c100b4a5392ad238d42066814/preds")
df.to_csv(savepath / "oncograde_best.csv", index=False)

# %%
preds = L(preds)

# %%
colors = np.array([[0, 0, 255],
                   [255, 0, 0],
                   [0, 255, 0]])

# %%
all_slides = files.map(lambda x: x.parent.name)

# %%
slides = all_slides.unique()

# %%
all_slides = np.array(all_slides)

# %%
ncols = 3
nrows = int(np.ceil(len(slides) / ncols))
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols*5, nrows*8))
for ax, slide in tqdm(zip(axs.flatten(), slides), total=len(slides)):
    idxs = np.argwhere(all_slides == slide)
    slide_preds = preds[idxs]
    slide_files = files[idxs]
    x_coords = slide_files.map(lambda x: int(x.stem.split('_')[-2])//598)
    y_coords = slide_files.map(lambda x: int(x.stem.split('_')[-1])//598)
    h = max(y_coords) + 1
    w = max(x_coords) + 1
    mask = np.zeros((h, w, 3), dtype = np.uint8)
    mask[(y_coords, x_coords)] = colors[slide_preds]
    ax.axis("off")
    ax.set_title(slide)
    ax.imshow(mask)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
#df = pd.read_csv(hparams.patch_classes, index_col='patchId')
def get_filt(ds):
    def filt(x):
        return ds in x.stem
    return filt

# %%
p04_items, p04_labels = get_items(hparams.data, lambda x: x.parts[-3], extensions=['.png'], filterfunc = get_filt('PACS04'))

# %%
p05_items, p05_labels = get_items(hparams.data, lambda x: x.parts[-3], extensions=['.png'], filterfunc = get_filt('PACS05'))

# %%
p08_items, p08_labels = get_items(hparams.data, lambda x: x.parts[-3], extensions=['.png'], filterfunc = get_filt('PACS08'))

# %%
hparams.open_mode = 'H'
hparams.transforms = 1
hparams.model = 'cbr_5_32_4'
#hparams.loss = 'mse'
hparams.size = 299
hparams.gpus = [0]
hparams.filt = 'all'
hparams.batch_size = 16
hparams.patch_classes = None
hparams.norm_csv = None
hparams.concept_classes = None
hparams.level = 2
hparams.loss = 'mse'
# hparams.train_percent = 0.01
hparams.datafolder = Path('/data/DeepLearning/SCHWOB_Robin/Patches_normacolor_299/Patches_299_4')
hparams.data_csv = Path('/home/DeepLearning/grade_classif/csvs/normacolor_scans.csv')

# %%
norm = Normalizer(hparams)

# %%
dm = NormDataModule(hparams)

# %%
dm.setup()

# %%
norm.fit(dm)

# %%
norm.load('1371a8451df344689f213e8db008ed71')

# %%
norm.freeze()

# %%
dm.data.valid._ds.items = p04_items
dm.data.valid._ds.labels = p04_items

# %%
norm.data.test = norm.data.valid

# %% [raw]
# logger = CometLogger(api_key=os.environ['COMET_API_KEY'], workspace='schwobr', save_dir=norm.save_path, project_name='grade-classif')
# logger.experiment.add_tag('norm' if isinstance(norm, Normalizer) else 'classif')
# ckpt_path = norm.save_path/'lightning_logs'/f'version_{logger.version}'/'checkpoints'
# ckpt_callback = ModelCheckpoint(ckpt_path, save_top_k=3)
# trainer = pl.Trainer(gpus=norm.hparams.gpus, checkpoint_callback=ckpt_callback, logger=logger, min_epochs=norm.hparams.epochs, max_epochs=norm.hparams.epochs)
# norm.version = trainer.logger.version

# %% [raw]
# trainer.test(norm)

# %%
len(dm.data.valid)
# Out:
# 0

# %%
l = np.random.randint(len(dm.data.valid), size=64)

# %%
fig, axs = plt.subplots(8, 8, figsize=(40, 40))
for n, ax1 in enumerate(axs):
    x = []
    for i in range(8):
        k = l[8*n+i]
        img, _ = dm.data.valid[k]
        x.append(img)
    x = torch.stack(x).to(norm.main_device)
    #x = _open_functions[norm.hparams.open_mode](x)
    x = norm.predict(x).detach().clamp(0, 1)
    x = x.cpu().numpy().transpose(0, 2, 3, 1)
    for im, ax in zip(x, ax1):
        ax.imshow(im)
        ax.axis('off')

# %%
fig, axs = plt.subplots(8, 8, figsize=(40, 40))
for n, ax in enumerate(axs.flatten()):
    k = l[n]
    _, img = dm.data.valid[k]
    img = img.cpu().numpy().transpose(1, 2, 0)
    ax.imshow(img)
    ax.axis('off')

# %%
norm.show_results(16, 6)

# %%
fig, axs = plt.subplots(2, 3, figsize=(24, 16))
fn = np.random.choice(p08_items)
x = loader(fn)[362:661, 362:661]
axs[0, 0].imshow(x)
axs[0, 0].axis('off')
for ax in axs.flatten()[1:]:
    x = rgb2hed(x)[..., 0].astype(np.float32)
    x = (x + 0.7) / 0.46
    x = np.stack((x, x, x), axis=-1)
    x = np_to_tensor(x, 'image')[None]
    x = x.to(norm.main_device)
    x = norm.predict(x).detach().clamp(0, 1)
    x = x.cpu().numpy().transpose(0, 2, 3, 1)[0]
    ax.imshow(x)
    ax.axis('off')

# %%
from albumentations import CenterCrop

# %%
patch_classes_df = pd.read_csv('/data/DeepLearning/SCHWOB_Robin/Patches_1024/Patches_1024_1/patch_classes.csv', index_col='patchId')
def filt(x):
    return patch_classes_df.loc[x.stem, 'type'] == 'K'

data = (ImageClassifDataset.
        from_folder(Path('/data/DeepLearning/SCHWOB_Robin/Patches_299/Patches_299_1/'), lambda x: x.parts[-3], classes=['1', '3'], extensions=['.png'], open_mode='RGB').
        split_by_csv(hparams.data_csv.parent/'scans.csv').
        to_tensor(tfm_y=False))

# %%
fig, axs = plt.subplots(8, 2, figsize=(10, 40))
batch = []
for _ in axs:
    i = np.random.randint(len(data.train))
    im, _ = data.train[i]
    batch.append(im)
x = torch.stack(batch).to(norm.main_device)
y = norm.predict(x).clamp(0, 1).detach().cpu()
for ax, im, pred in zip(axs, batch, y):
    im = im.numpy().transpose(1, 2, 0)
    pred = pred.numpy().transpose(1, 2, 0)
    ax[0].imshow(im)
    ax[0].axis('off')
    ax[1].imshow(pred)
    ax[1].axis('off')
